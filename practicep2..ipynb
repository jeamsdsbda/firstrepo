# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Downloads\marksheet.csv")
df
# Out:
#    S.No Gender   Data Science    WT     AI
# 0     1       M          23.0  66.0    NaN
# 1     2       F          56.0  56.0   65.0
# 2     3       M          64.0  56.0  123.0
# 3     4       F           NaN  65.0   51.0
# 4     5       M          64.0   NaN   51.0
# 5     6       F          64.0   NaN   51.0
# 6     7       M           NaN  64.0   85.0
# 7     8       F          44.0  55.0   35.0
# 8     9       M          46.0  35.0    NaN
# 9    10       F          54.0  64.0   68.0

# %%
df.isnull()
# Out:
#     S.No  Gender   Data Science     WT     AI
# 0  False    False         False  False   True
# 1  False    False         False  False  False
# 2  False    False         False  False  False
# 3  False    False          True  False  False
# 4  False    False         False   True  False
# 5  False    False         False   True  False
# 6  False    False          True  False  False
# 7  False    False         False  False  False
# 8  False    False         False  False   True
# 9  False    False         False  False  False

# %%
df.isnull()
# Out:
#     S.No  Gender   Data Science     WT     AI
# 0  False    False         False  False   True
# 1  False    False         False  False  False
# 2  False    False         False  False  False
# 3  False    False          True  False  False
# 4  False    False         False   True  False
# 5  False    False         False   True  False
# 6  False    False          True  False  False
# 7  False    False         False  False  False
# 8  False    False         False  False   True
# 9  False    False         False  False  False

# %%
df.dropna()
# Out:
#    S.No Gender   Data Science    WT     AI
# 1     2       F          56.0  56.0   65.0
# 2     3       M          64.0  56.0  123.0
# 7     8       F          44.0  55.0   35.0
# 9    10       F          54.0  64.0   68.0

# %%
df.dropna(how="all")
# Out:
#    S.No Gender   Data Science    WT     AI
# 0     1       M          23.0  66.0    NaN
# 1     2       F          56.0  56.0   65.0
# 2     3       M          64.0  56.0  123.0
# 3     4       F           NaN  65.0   51.0
# 4     5       M          64.0   NaN   51.0
# 5     6       F          64.0   NaN   51.0
# 6     7       M           NaN  64.0   85.0
# 7     8       F          44.0  55.0   35.0
# 8     9       M          46.0  35.0    NaN
# 9    10       F          54.0  64.0   68.0

# %%
print("Students who have greater than 40 marks in WT are",np.where(df['WT']>40))
# Out:
# Students who have greater than 40 marks in WT are (array([0, 1, 2, 3, 6, 7, 9], dtype=int64),)

# %%
print("Students who have greater than 50 marks in AI are",np.where(df['AI']>50))
# Out:
# Students who have greater than 50 marks in AI are (array([1, 2, 3, 4, 5, 6, 9], dtype=int64),)

# %%
f=df['AI'].mean()
df['AI'].fillna(value=f,inplace=True)
df
# Out:
#    S.No Gender   Data Science    WT       AI
# 0     1       M          23.0  66.0   66.125
# 1     2       F          56.0  56.0   65.000
# 2     3       M          64.0  56.0  123.000
# 3     4       F           NaN  65.0   51.000
# 4     5       M          64.0   NaN   51.000
# 5     6       F          64.0   NaN   51.000
# 6     7       M           NaN  64.0   85.000
# 7     8       F          44.0  55.0   35.000
# 8     9       M          46.0  35.0   66.125
# 9    10       F          54.0  64.0   68.000

# %%
f=df['AI'].mean()
df['AI'].fillna(value=f,inplace=True)
df
# Out:
#    S.No Gender   Data Science    WT       AI
# 0     1       M          23.0  66.0   66.125
# 1     2       F          56.0  56.0   65.000
# 2     3       M          64.0  56.0  123.000
# 3     4       F           NaN  65.0   51.000
# 4     5       M          64.0   NaN   51.000
# 5     6       F          64.0   NaN   51.000
# 6     7       M           NaN  64.0   85.000
# 7     8       F          44.0  55.0   35.000
# 8     9       M          46.0  35.0   66.125
# 9    10       F          54.0  64.0   68.000

# %%
f=df['WT'].mean()
df['WT'].fillna(value=f,inplace=True)
df
# Out:
#    S.No Gender   Data Science      WT       AI
# 0     1       M          23.0  66.000   66.125
# 1     2       F          56.0  56.000   65.000
# 2     3       M          64.0  56.000  123.000
# 3     4       F           NaN  65.000   51.000
# 4     5       M          64.0  57.625   51.000
# 5     6       F          64.0  57.625   51.000
# 6     7       M           NaN  64.000   85.000
# 7     8       F          44.0  55.000   35.000
# 8     9       M          46.0  35.000   66.125
# 9    10       F          54.0  64.000   68.000

# %%
import matplotlib.pyplot as plt
print("AI makrs in pie char format\n\n",df['AI'].plot(kind='bar'))
# Out:
# AI makrs in pie char format
#
#  AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print("WT marks will display in the pie chart format\n\n",df['WT'].plot(kind='bar'))
# Out:
# WT marks will display in the pie chart format
#
#  AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df.corr()
# Out:
#                   S.No  Data Science        WT        AI
# S.No          1.000000      0.165346 -0.352505 -0.237968
# Data Science  0.165346      1.000000 -0.109565  0.222566
# WT           -0.352505     -0.109565  1.000000  0.006050
# AI           -0.237968      0.222566  0.006050  1.000000

# %%
import seaborn as s
s.pairplot(df)

# %%
print("pair plot of AI objects is",plt.plot(df['AI']))
# Out:
# pair plot of AI objects is [<matplotlib.lines.Line2D object at 0x000001D2143D3160>]

# %%
print("pair plot of WT objects is",plt.plot(df['WT']))
# Out:
# pair plot of WT objects is [<matplotlib.lines.Line2D object at 0x000001D21441CF40>]

# %%
list.columns(df.columns)
